# %% [markdown]
# **To import required libraries**

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

import nltk                                   # To use the NLTK (Natural Language Toolkit) library, particularly for the tokenization NLP task
nltk.download('stopwords')                    # To download the list of stopwords (i.e., common words) from the NLTK corpus
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))  # To create a list of English stopwords

from collections import Counter # Counter is a subclass of dict that is used to count occurrences of elements in an iterable
import string                   # Contains functions and constants related to string processing
import re                       # The re module provides support for regular expressions (pattern matching, searching, and modifying within strings)
import seaborn as sns           # Seaborn is a Python data visualization library for statistical data visualization

from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split # To use sklearn libraries to split dataset into train and test sets
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Device Initialization**

# %%
if torch.cuda.is_available:
    device = torch.device("cuda")
    print("GPU assigned for processing!\n")
else:
    device = torch.device("cpu")
    print("CPU assigned for processing!\n")
# Out:
# GPU assigned for processing!

# %% [markdown]
# **Task 1-1: To load and explore the dataset (Columns are identified)**

# %%
df = pd.read_csv('/content/drive/MyDrive/Notebooks_DL/IMDB_dataset/IMDB_Dataset.csv')
df.head(10)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive
# 6  I sure would like to see a resurrection of a u...  positive
# 7  This show was an amazing, fresh & innovative i...  negative
# 8  Encouraged by the positive comments about this...  negative
# 9  If you like original gut wrenching laughter yo...  positive

# %% [markdown]
# **Task 1-2: To split Dataset into train and test (i.e., 80-20)**

# %%
x, y = df['review'].values, df['sentiment'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)
print(f'shape of train data is {x_train.shape}')
print(f'shape of test data is {x_test.shape}\n')
# Out:
# shape of train data is (40000,)
# shape of test data is (10000,)

# %% [markdown]
# **Task 1-3: To clean the input word by removing non-word characters, white spaces, and digits exploiting "re"**

# %%
def clean_string(s):
    s = re.sub(r"[^\w\s]", '', s) # To replace all non-word characters (everything except numbers and letters) with no-space
    s = re.sub(r"\s+", '', s)     # To replace all runs of whitespaces with no-space
    s = re.sub(r"\d", '', s)      # To replace digits with no-space
    return s

# %% [markdown]
# **Task 1-4: To convert a list of tokenized sentences into a fixed-length numerical matrix by Zero-padding or Truncating each sentence to length seq_len (If review is shorter than seq_len, It is right-aligned, with zeros in the front. If review is longer than seq_len, It is truncated from the end, keeping the first seq_len tokens)**

# %%
def padding (sentences, seq_len):
    features = np.zeros((len(sentences), seq_len), dtype=int)
    for idx, review in enumerate(sentences): # This iterates over sentences matrix which includes several reviews (a list of numerical tokens)
        if len(review) != 0:                 # Ensures the sentence is not empty
            features[idx, -len(review):] = np.array(review)[:seq_len]
    return features

# %% [markdown]
# **Task 1-5: The following function cleans text, builds a limited vocabulary, converts sentences into integer token sequences, encodes labels, and pads sequences to a fixed length for use in next NLP models**

# %%
def tockenize(x_train, y_train, x_val, y_val, stop_words):

    word_list = []
    for sent in x_train:
        for word in sent.lower().split():
            word = clean_string(word)                 # First, it removes non-word characters, white spaces, and digits from each word of a sentence
            if word not in stop_words and word != '': # Second, it stores the word if it is not a stop_word or a no-space
                word_list.append(word)

    # This performs vocabulary construction for NLP preprocessing. It counts word frequencies and creates a corpus (a dictionary of word frequency),
    # selects the top 1000 most frequent words, and assigns each word a unique integer index for numerical representation.
    corpus = Counter(word_list)
    corpus_sorted = sorted(corpus, key=corpus.get, reverse=True)[:1000]
    one_hot_dict = {w:i+1 for i, w in enumerate(corpus_sorted)}
    print(corpus)
    print(corpus_sorted)
    print(one_hot_dict)

    # Tockenize converts a list of sentences (x_train) into a list of numerical indices, mapping words to their corresponding integer values in one_hot_dict
    # It is a common preprocessing step in Natural Language Processing (NLP) before feeding data into machine learning models
    final_list_train = []
    final_list_test  = []
    for sent in x_train:
        final_list_train.append([one_hot_dict[clean_string(word)] for word in sent.lower().split() if clean_string(word) in one_hot_dict.keys()])

    for sent in x_val:
        final_list_test.append([one_hot_dict[clean_string(word)] for word in sent.lower().split() if clean_string(word) in one_hot_dict.keys()])

    y_train_encoded = [1 if label =='positive' else 0 for label in y_train]
    y_test_encoded  = [1 if label =='positive' else 0 for label in y_val]

    # Padding to make all sequences of equal length
    max_length = 500
    x_train_padded = padding (final_list_train, max_length)
    x_test_padded  = padding (final_list_test,  max_length)

    return np.array(x_train_padded), np.array(y_train_encoded), np.array(x_test_padded), np.array(y_test_encoded), one_hot_dict

# %% [markdown]
# **Task 1-6: Apply the defined tockenization function**

# %%
x_train_padded, y_train_encoded, x_test_padded, y_test_encoded, vocab = tockenize(x_train, y_train, x_test, y_test, stop_words)

print(f'\nLength of vocabulary is {len(vocab)} and it is sorted as most frequently used words first')
# Out:
# Counter({'br': 91994, 'movie': 66728, 'film': 59651, 'one': 40718, 'like': 31096, 'good': 22841, 'even': 19688, 'would': 19158, 'time': 18704, 'really': 18349, 'see': 18052, 'story': 17619, 'much': 15192, 'well': 14971, 'get': 14606, 'also': 14285, 'great': 14223, 'bad': 14210, 'people': 13960, 'first': 13807, 'dont': 13675, 'made': 12303, 'films': 12295, 'make': 12254, 'movies': 12252, 'could': 12044, 'way': 11959, 'characters': 11700, 'think': 11324, 'watch': 10895, 'many': 10677, 'seen': 10523, 'two': 10426, 'character': 10317, 'never': 10311, 'love': 10121, 'acting': 10067, 'plot': 10019, 'best': 9907, 'little': 9891, 'know': 9788, 'show': 9622, 'life': 9358, 'ever': 9282, 'better': 8870, 'still': 8529, 'say': 8482, 'scene': 8471, 'end': 8424, 'man': 8184, 'scenes': 8088, 'something': 7802, 'go': 7677, 'im': 7587, 'back': 7386, 'watching': 7242, 'real': 7236, 'thing': 7075, 'actors': 7055, 'doesnt': 7046, 'didnt': 7008, 'years': 6958, 'another': 6848, 'actually': 6735, 'funny': 6688, 'though': 6683, 'makes': 6664, 'nothing': 6592, 'find': 6514, 'look': 6508, 'going': 6446, 'lot': 6414, 'new': 6385, 'every': 6381, 'work': 6381, 'old': 6268, 'us': 6129, 'part': 6084, 'cant': 6051, 'thats': 5958, 'director': 5889, 'things': 5811, 'cast': 5808, 'want': 5797, 'quite': 5784, 'pretty': 5743, 'around': 5643, 'seems': 5611, 'young': 5559, 'got': 5540, 'take': 5494, 'however': 5465, 'fact': 5464, 'world': 5393, 'horror': 5372, 'big': 5367, 'thought': 5338, 'enough': 5304, 'ive': 5298, 'give': 5251, 'may': 5235, 'isnt': 5097, 'saw': 5086, 'without': 5066, 'always': 5065, 'long': 5031, 'gets': 5005, 'music': 4996, 'right': 4975, 'must': 4968, 'come': 4965, 'original': 4951, 'almost': 4945, 'times': 4906, 'theres': 4899, 'comedy': 4892, 'whole': 4850, 'least': 4836, 'role': 4834, 'interesting': 4829, 'series': 4797, 'action': 4772, 'guy': 4765, 'bit': 4722, 'point': 4685, 'done': 4638, 'script': 4587, 'anything': 4578, 'far': 4569, 'feel': 4553, 'hes': 4551, 'minutes': 4519, 'might': 4515, 'probably': 4472, 'since': 4462, 'last': 4429, 'family': 4391, 'kind': 4366, 'performance': 4294, 'away': 4233, 'yet': 4211, 'tv': 4201, 'rather': 4200, 'worst': 4163, 'fun': 4141, 'anyone': 4134, 'sure': 4128, 'played': 4118, 'found': 4086, 'making': 4028, 'girl': 3992, 'believe': 3969, 'although': 3932, 'woman': 3923, 'shows': 3915, 'trying': 3897, 'course': 3881, 'especially': 3847, 'comes': 3820, 'hard': 3803, 'put': 3781, 'goes': 3780, 'everything': 3771, 'day': 3734, 'worth': 3699, 'maybe': 3688, 'main': 3673, 'looking': 3661, 'different': 3654, 'looks': 3624, 'ending': 3603, 'watched': 3601, 'three': 3573, 'dvd': 3571, 'place': 3566, 'wasnt': 3562, 'sense': 3562, 'book': 3528, 'screen': 3525, 'set': 3525, 'plays': 3511, 'someone': 3501, 'reason': 3495, 'true': 3488, 'money': 3482, 'play': 3478, 'effects': 3468, 'said': 3460, 'job': 3436, 'together': 3431, 'actor': 3388, 'takes': 3381, 'instead': 3371, 'seem': 3363, 'later': 3325, 'everyone': 3322, 'special': 3319, 'beautiful': 3310, 'american': 3298, 'audience': 3271, 'seeing': 3263, 'john': 3261, 'version': 3237, 'excellent': 3235, 'left': 3226, 'war': 3224, 'idea': 3192, 'shot': 3146, 'simply': 3112, 'night': 3111, 'black': 3107, 'high': 3094, 'youre': 3075, 'fan': 3035, 'used': 3032, 'house': 3009, 'completely': 3004, 'nice': 3001, 'kids': 2995, 'wife': 2976, 'poor': 2975, 'death': 2962, 'along': 2952, 'read': 2936, 'else': 2924, 'second': 2915, 'help': 2905, 'friends': 2873, 'year': 2870, 'use': 2865, 'short': 2856, 'try': 2846, 'mind': 2837, 'enjoy': 2836, 'given': 2834, 'star': 2832, 'men': 2832, 'half': 2831, 'less': 2812, 'home': 2808, 'need': 2808, 'boring': 2782, 'rest': 2778, 'either': 2769, 'truly': 2746, 'line': 2736, 'classic': 2729, 'next': 2725, 'dead': 2714, 'recommend': 2713, 'stupid': 2713, 'performances': 2711, 'production': 2710, 'couple': 2698, 'wrong': 2698, 'start': 2683, 'remember': 2670, 'hollywood': 2651, 'school': 2646, 'came': 2646, 'full': 2637, 'tell': 2633, 'wom ...
# ['br', 'movie', 'film', 'one', 'like', 'good', 'even', 'would', 'time', 'really', 'see', 'story', 'much', 'well', 'get', 'also', 'great', 'bad', 'people', 'first', 'dont', 'made', 'films', 'make', 'movies', 'could', 'way', 'characters', 'think', 'watch', 'many', 'seen', 'two', 'character', 'never', 'love', 'acting', 'plot', 'best', 'little', 'know', 'show', 'life', 'ever', 'better', 'still', 'say', 'scene', 'end', 'man', 'scenes', 'something', 'go', 'im', 'back', 'watching', 'real', 'thing', 'actors', 'doesnt', 'didnt', 'years', 'another', 'actually', 'funny', 'though', 'makes', 'nothing', 'find', 'look', 'going', 'lot', 'new', 'every', 'work', 'old', 'us', 'part', 'cant', 'thats', 'director', 'things', 'cast', 'want', 'quite', 'pretty', 'around', 'seems', 'young', 'got', 'take', 'however', 'fact', 'world', 'horror', 'big', 'thought', 'enough', 'ive', 'give', 'may', 'isnt', 'saw', 'without', 'always', 'long', 'gets', 'music', 'right', 'must', 'come', 'original', 'almost', 'times', 'theres', 'comedy', 'whole', 'least', 'role', 'interesting', 'series', 'action', 'guy', 'bit', 'point', 'done', 'script', 'anything', 'far', 'feel', 'hes', 'minutes', 'might', 'probably', 'since', 'last', 'family', 'kind', 'performance', 'away', 'yet', 'tv', 'rather', 'worst', 'fun', 'anyone', 'sure', 'played', 'found', 'making', 'girl', 'believe', 'although', 'woman', 'shows', 'trying', 'course', 'especially', 'comes', 'hard', 'put', 'goes', 'everything', 'day', 'worth', 'maybe', 'main', 'looking', 'different', 'looks', 'ending', 'watched', 'three', 'dvd', 'place', 'wasnt', 'sense', 'book', 'screen', 'set', 'plays', 'someone', 'reason', 'true', 'money', 'play', 'effects', 'said', 'job', 'together', 'actor', 'takes', 'instead', 'seem', 'later', 'everyone', 'special', 'beautiful', 'american', 'audience', 'seeing', 'john', 'version', 'excellent', 'left', 'war', 'idea', 'shot', 'simply', 'night', 'black', 'high', 'youre', 'fan', 'used', 'house', 'completely', 'nice', 'kids', 'wife', 'poor', 'death', 'along', 'read', 'else', 'second', 'help', 'friends', 'year', 'use', 'short', 'try', 'mind', 'enjoy', 'given', 'star', 'men', 'half', 'less', 'home', 'need', 'boring', 'rest', 'either', 'truly', 'line', 'classic', 'next', 'dead', 'recommend', 'stupid', 'performances', 'production', 'couple', 'wrong', 'start', 'remember', 'hollywood', 'school', 'came', 'full', 'tell', 'women', 'let', 'understand', 'getting', 'terrible', 'camera', 'perhaps', 'father', 'awful', 'keep', 'others', 'sex', 'mean', 'moments', 'wonderful', 'definitely', 'playing', 'video', 'budget', 'small', 'perfect', 'often', 'absolutely', 'episode', 'name', 'person', 'face', 'gives', 'top', 'human', 'dialogue', 'liked', 'went', 'couldnt', 'early', 'finally', 'guys', 'lines', 'piece', 'title', 'certainly', 'become', 'loved', 'stars', 'case', 'sort', 'entire', 'head', 'yes', 'hope', 'written', 'felt', 'style', 'worse', 'live', 'overall', 'lost', 'picture', 'supposed', 'laugh', 'mr', 'waste', 'several', 'mother', 'problem', 'entertaining', 'based', 'sound', 'seemed', 'totally', 'boy', 'oh', 'shes', 'beginning', 'dark', 'friend', 'id', 'cinema', 'humor', 'final', 'despite', 'direction', 'guess', 'wanted', 'lead', 'youll', 'care', 'fans', 'example', 'becomes', 'called', 'drama', 'throughout', 'wont', 'game', 'low', 'already', 'evil', 'lives', 'able', 'turn', 'unfortunately', 'children', 'days', 'girls', 'white', 'wants', 'fine', 'theyre', 'michael', 'quality', 'writing', 'history', 'works', 'act', 'amazing', 'tries', 'horrible', 'gave', 'kill', 'killer', 'enjoyed', 'turns', 'past', 'parts', 'side', 'behind', 'favorite', 'eyes', 'son', 'flick', 'run', 'brilliant', 'obviously', 'stuff', 'ones', 'says', 'directed', 'expect', 'sometimes', 'starts', 'matter', 'car', 'viewer', 'town', 'ill', 'thinking', 'decent', 'highly', 'art', 'heart', 'killed', 'took', 'soon', 'city', 'actress', 'late', 'happens', 'feeling', 'group', 'genre', 'heard', 'kid', 'except', 'child', 'hell', 'blood', 'fight', 'hour', 'police',  ...
# {'br': 1, 'movie': 2, 'film': 3, 'one': 4, 'like': 5, 'good': 6, 'even': 7, 'would': 8, 'time': 9, 'really': 10, 'see': 11, 'story': 12, 'much': 13, 'well': 14, 'get': 15, 'also': 16, 'great': 17, 'bad': 18, 'people': 19, 'first': 20, 'dont': 21, 'made': 22, 'films': 23, 'make': 24, 'movies': 25, 'could': 26, 'way': 27, 'characters': 28, 'think': 29, 'watch': 30, 'many': 31, 'seen': 32, 'two': 33, 'character': 34, 'never': 35, 'love': 36, 'acting': 37, 'plot': 38, 'best': 39, 'little': 40, 'know': 41, 'show': 42, 'life': 43, 'ever': 44, 'better': 45, 'still': 46, 'say': 47, 'scene': 48, 'end': 49, 'man': 50, 'scenes': 51, 'something': 52, 'go': 53, 'im': 54, 'back': 55, 'watching': 56, 'real': 57, 'thing': 58, 'actors': 59, 'doesnt': 60, 'didnt': 61, 'years': 62, 'another': 63, 'actually': 64, 'funny': 65, 'though': 66, 'makes': 67, 'nothing': 68, 'find': 69, 'look': 70, 'going': 71, 'lot': 72, 'new': 73, 'every': 74, 'work': 75, 'old': 76, 'us': 77, 'part': 78, 'cant': 79, 'thats': 80, 'director': 81, 'things': 82, 'cast': 83, 'want': 84, 'quite': 85, 'pretty': 86, 'around': 87, 'seems': 88, 'young': 89, 'got': 90, 'take': 91, 'however': 92, 'fact': 93, 'world': 94, 'horror': 95, 'big': 96, 'thought': 97, 'enough': 98, 'ive': 99, 'give': 100, 'may': 101, 'isnt': 102, 'saw': 103, 'without': 104, 'always': 105, 'long': 106, 'gets': 107, 'music': 108, 'right': 109, 'must': 110, 'come': 111, 'original': 112, 'almost': 113, 'times': 114, 'theres': 115, 'comedy': 116, 'whole': 117, 'least': 118, 'role': 119, 'interesting': 120, 'series': 121, 'action': 122, 'guy': 123, 'bit': 124, 'point': 125, 'done': 126, 'script': 127, 'anything': 128, 'far': 129, 'feel': 130, 'hes': 131, 'minutes': 132, 'might': 133, 'probably': 134, 'since': 135, 'last': 136, 'family': 137, 'kind': 138, 'performance': 139, 'away': 140, 'yet': 141, 'tv': 142, 'rather': 143, 'worst': 144, 'fun': 145, 'anyone': 146, 'sure': 147, 'played': 148, 'found': 149, 'making': 150, 'girl': 151, 'believe': 152, 'although': 153, 'woman': 154, 'shows': 155, 'trying': 156, 'course': 157, 'especially': 158, 'comes': 159, 'hard': 160, 'put': 161, 'goes': 162, 'everything': 163, 'day': 164, 'worth': 165, 'maybe': 166, 'main': 167, 'looking': 168, 'different': 169, 'looks': 170, 'ending': 171, 'watched': 172, 'three': 173, 'dvd': 174, 'place': 175, 'wasnt': 176, 'sense': 177, 'book': 178, 'screen': 179, 'set': 180, 'plays': 181, 'someone': 182, 'reason': 183, 'true': 184, 'money': 185, 'play': 186, 'effects': 187, 'said': 188, 'job': 189, 'together': 190, 'actor': 191, 'takes': 192, 'instead': 193, 'seem': 194, 'later': 195, 'everyone': 196, 'special': 197, 'beautiful': 198, 'american': 199, 'audience': 200, 'seeing': 201, 'john': 202, 'version': 203, 'excellent': 204, 'left': 205, 'war': 206, 'idea': 207, 'shot': 208, 'simply': 209, 'night': 210, 'black': 211, 'high': 212, 'youre': 213, 'fan': 214, 'used': 215, 'house': 216, 'completely': 217, 'nice': 218, 'kids': 219, 'wife': 220, 'poor': 221, 'death': 222, 'along': 223, 'read': 224, 'else': 225, 'second': 226, 'help': 227, 'friends': 228, 'year': 229, 'use': 230, 'short': 231, 'try': 232, 'mind': 233, 'enjoy': 234, 'given': 235, 'star': 236, 'men': 237, 'half': 238, 'less': 239, 'home': 240, 'need': 241, 'boring': 242, 'rest': 243, 'either': 244, 'truly': 245, 'line': 246, 'classic': 247, 'next': 248, 'dead': 249, 'recommend': 250, 'stupid': 251, 'performances': 252, 'production': 253, 'couple': 254, 'wrong': 255, 'start': 256, 'remember': 257, 'hollywood': 258, 'school': 259, 'came': 260, 'full': 261, 'tell': 262, 'women': 263, 'let': 264, 'understand': 265, 'getting': 266, 'terrible': 267, 'camera': 268, 'perhaps': 269, 'father': 270, 'awful': 271, 'keep': 272, 'others': 273, 'sex': 274, 'mean': 275, 'moments': 276, 'wonderful': 277, 'definitely': 278, 'playing': 279, 'video': 280, 'budget': 281, 'small': 282, 'perfect': 283, 'often': 284, 'absolutely': 285, 'episode': 286, 'name': 287, 'person': 288, 'face': 289, 'gives': 29 ...
#
# Length of vocabulary is 1000 and it is sorted as most frequently used words first

# %% [markdown]
# **Task 1-7: Finally, convert NumPy arrays to Tensors to define PyTorch DataLoader**

# %%
train_data = TensorDataset(torch.from_numpy(x_train_padded), torch.from_numpy(y_train_encoded))
valid_data = TensorDataset(torch.from_numpy(x_test_padded), torch.from_numpy(y_test_encoded))

batch_size = 75
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
valid_loader = DataLoader(valid_data, shuffle=True, batch_size=batch_size)

# Data Size Explaoration
print(f"Length train_loader is: {len(train_loader)}")
print(f"Length test_loader is: {len(valid_loader)}")
print(f"Each Sample has the size of: {train_data[0][0].size()}")
# Out:
# Length train_loader is: 534
# Length test_loader is: 134
# Each Sample has the size of: torch.Size([500])

# %% [markdown]
# **Task 2-1: Build an RNN Model (Utilizing LSTM, SimpleRNN, GRU, Dropout, Linear, and Sigmoid Layers)**

# %%
class SentimentRNN(nn.Module):
    def __init__(self, n_layers, vocab_size, output_dim, hidden_dim, embedding_dim, drop_prob=0.2):
        super(SentimentRNN,self).__init__()

        self.n_layers   = n_layers
        self.vocab_size = vocab_size
        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.drop_prob  = drop_prob

        # Embedding layer
        # Converts categorical word indices (sparse and high-dimensional) into meaningful dense vectors of fixed lower size
        # Learns embeddings during training (instead of using one-hot encoding). Captures semantic relationships between words
        # Output: batch_size * sequence_length * embedding_dim
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # LSTM layer
        # Takes input embeddings (word representations from nn.Embedding)
        # Processes them sequentially (one step at a time)
        # Updates the hidden state (h_t) and cell state (c_t) at each step
        # Passes the final hidden state (h_t) to the next layer or for prediction

        self.gru = nn.GRU(input_size=embedding_dim, hidden_size=self.hidden_dim, num_layers=n_layers, batch_first=True)
        # self.rnn = nn.RNN(input_size=embedding_dim, hidden_size=self.hidden_dim, num_layers=n_layers, batch_first=True)
        # self.lstm = nn.LSTM(input_size=embedding_dim, hidden_size=self.hidden_dim, num_layers=n_layers, batch_first=True)

        # Dropout layer
        self.dropout = nn.Dropout(drop_prob)

        # Linear layer
        self.fc = nn.Linear(self.hidden_dim, output_dim)

        # Sigmoid layer
        self.sig = nn.Sigmoid()

    def forward(self, x, hidden):

        batch_size = x.size(0)

        # Embeddings
        embeds = self.embedding(x)

        # LSTM feeding
        # The input and output tensors in LSTM layer are provided as (batch, seq, feature), so we need to flatten the output
        # lstm_out, hidden = self.lstm(embeds, hidden)
        # lstm_out = lstm_out.contiguous().view(-1, self.hidden_dim)
        # rnn_out, hidden = self.rnn(embeds, hidden)
        # rnn_out = rnn_out.contiguous().view(-1, self.hidden_dim)
        gru_out, hidden = self.gru(embeds, hidden)
        gru_out = gru_out.contiguous().view(-1, self.hidden_dim)

        # dropout and fully connected layer
        # out = self.dropout(lstm_out)
        # out = self.dropout(rnn_out)
        out = self.dropout(gru_out)
        out = self.fc(out)
        sig_out = self.sig(out)

        # Reshape to be batch_size first
        sig_out = sig_out.view(batch_size, -1)

        # To get the prediction related to the Last Timestep among all timesteps of one sentence
        sig_out = sig_out[:, -1]

        # Returns the last sigmoid output (i.e., predicted lables) and hidden state
        return sig_out, hidden

    # for LSTM initialization which has a cell state
    '''
    def init_hidden(self, batch_size):

        # Initializes the hidden state and cell state of the LSTM
        h0 = torch.zeros((self.n_layers, batch_size, self.hidden_dim)).to(device)
        c0 = torch.zeros((self.n_layers, batch_size, self.hidden_dim)).to(device)
        hidden = (h0, c0)

        return hidden
    '''

    # for SimpleRNN and GRU initialization which don't have a cell state
    def init_hidden(self, batch_size):
        h0 = torch.zeros((self.n_layers, batch_size, self.hidden_dim)).to(device)
        return h0

# %% [markdown]
# **Task 2-2: Initializing the defined RNN Model and Optimizer**

# %%
n_layers = 2                # Number of stacked LSTM layers
vocab_size = len(vocab) + 1 # Plus 1 for padding
embedding_dim = 64          # The size of each embedded vector (embedding size)
output_dim = 1              # The number of output classes (e.g., 1 for binary classification)
hidden_dim = 256            # The number of features in the hidden state, or number of hidden units in each LSTM cell
drop_prob= 0.2

model = SentimentRNN(n_layers, vocab_size, output_dim, hidden_dim, embedding_dim, drop_prob)
model.to(device)
print(model)

LR = 0.001               # Learning Rate
criterion = nn.BCELoss() # Loss function: Binary Cross Entropy loss function
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# A function to calculate accuracy
def acc(pred, label):
    pred = torch.round(pred.squeeze())
    return torch.sum(pred == label.squeeze()).item()
# Out:
# SentimentRNN(
#   (embedding): Embedding(1001, 64)
#   (gru): GRU(64, 256, num_layers=2, batch_first=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (sig): Sigmoid()
# )

# %% [markdown]
# **Task 3: Train and Test the RNN Model**

# %%
clip_value = 5
epochs = 10
valid_loss_min = np.inf

# To track accuracy and loss for Train and Validation phases
epoch_tr_loss, epoch_vl_loss = [],[]
epoch_tr_acc,  epoch_vl_acc  = [],[]

for epoch in range(epochs):

    ### Training Phase starts here
    train_losses = []
    train_acc = 0.0
    model.train()

    # To initialize hidden state (Initialize once, update dynamically)
    h = None

    for inputs, labels in train_loader:

        inputs, labels = inputs.to(device), labels.to(device)

        batch_size = inputs.size(0)

        # If h is None (first batch) or batch size has changed (last batch), reinitialize
        if h is None or batch_size != h.size(1):
              h = model.init_hidden(batch_size).to(device)
        '''else:
              h = h[:, :batch_size, :].contiguous()  # Ensures correct size'''

        # h = tuple([each.data for each in h]) # Correct for LSTM
        h = h.data # Correct for SimpleRNN and GRU

        model.zero_grad()

        output, h = model(inputs, h)
        loss = criterion(output.squeeze(), labels.float()) # Calculate the loss and perform backpropagation
        loss.backward()
        train_losses.append(loss.item())
        correct = acc(output, labels) # Calculating Correct Predictions
        train_acc += correct

        # clip_grad_norm helps to prevent the exploding of gradients RNNs/LSTMs
        nn.utils.clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()

    ### Validation Phase starts here
    val_losses = []
    val_acc = 0.0
    model.eval()
    h_val = None  # Initialize once, update dynamically

    for inputs, labels in valid_loader:

        inputs, labels = inputs.to(device), labels.to(device)

        batch_size = inputs.size(0)

        # If h_val is None (first batch) or batch size has changed (last batch), reinitialize
        if h_val is None or batch_size != h_val.size(1):
              h_val = model.init_hidden(batch_size).to(device)
        '''else:
              h_val = h_val[:, :batch_size, :].contiguous() # Ensures correct size'''

        # h_val = tuple([each.data for each in h_val]) # Correct for LSTM
        h_val = h_val.detach() # Correct for SimpleRNN and GRU

        output, h_val = model(inputs, h_val)

        val_loss = criterion(output.squeeze(), labels.float())
        val_losses.append(val_loss.item())

        correct = acc(output, labels)
        val_acc += correct

    epoch_train_loss = np.mean(train_losses)
    epoch_val_loss   = np.mean(val_losses)
    epoch_train_acc  = train_acc/len(train_loader.dataset)
    epoch_val_acc    = val_acc/len(valid_loader.dataset)

    epoch_tr_loss.append(epoch_train_loss)
    epoch_vl_loss.append(epoch_val_loss)
    epoch_tr_acc.append(epoch_train_acc)
    epoch_vl_acc.append(epoch_val_acc)

    print(f'Epoch {epoch+1}')
    print(f'train_loss : {epoch_train_loss} val_loss : {epoch_val_loss}')
    print(f'train_accuracy : {epoch_train_acc*100} val_accuracy : {epoch_val_acc*100}')

    if epoch_val_loss <= valid_loss_min:
      print('Validation loss decreased from {:.6f} to {:.6f}. Saving model ...'.format(valid_loss_min, epoch_val_loss))
      valid_loss_min = epoch_val_loss

    print(40*'==')
# Out:
# Epoch 1
# train_loss : 0.47400647597143264 val_loss : 0.3635400296814406
# train_accuracy : 77.17500000000001 val_accuracy : 84.06
# Validation loss decreased from inf to 0.363540. Saving model ...
# ================================================================================
# Epoch 2
# train_loss : 0.337650812994898 val_loss : 0.3644002806117286
# train_accuracy : 85.47 val_accuracy : 84.11
# ================================================================================
# Epoch 3
# train_loss : 0.29476995247133664 val_loss : 0.32233692071775893
# train_accuracy : 87.655 val_accuracy : 86.04
# Validation loss decreased from 0.363540 to 0.322337. Saving model ...
# ================================================================================
# Epoch 4
# train_loss : 0.25537244586294955 val_loss : 0.33516773592625093
# train_accuracy : 89.525 val_accuracy : 85.91
# ================================================================================
# Epoch 5
# train_loss : 0.20476164996679802 val_loss : 0.3683507500299767
# train_accuracy : 91.9075 val_accuracy : 85.6
# ================================================================================
# Epoch 6
# train_loss : 0.13700388721452 val_loss : 0.4369681255141301
# train_accuracy : 94.85249999999999 val_accuracy : 84.47
# ================================================================================
# Epoch 7
# train_loss : 0.07263938406977649 val_loss : 0.6534019185424741
# train_accuracy : 97.3875 val_accuracy : 84.25
# ================================================================================
# Epoch 8
# train_loss : 0.041364147566121126 val_loss : 0.6835744582227806
# train_accuracy : 98.5825 val_accuracy : 84.34
# ================================================================================
# Epoch 9
# train_loss : 0.030292620471559208 val_loss : 0.7613911848904481
# train_accuracy : 98.925 val_accuracy : 83.65
# ================================================================================
# Epoch 10
# train_loss : 0.024297473149148274 val_loss : 0.8374860413483719
# train_accuracy : 99.22999999999999 val_accuracy : 84.04
# ================================================================================

# %% [markdown]
# **Task 4: Demonstration**

# %%
fig = plt.figure(figsize = (20, 6))
plt.subplot(1, 2, 1)
plt.plot(epoch_tr_acc, label='Training Acc')
plt.plot(epoch_vl_acc, label='Validation Acc')
plt.title("Accuracy")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epoch_tr_loss, label='Training loss')
plt.plot(epoch_vl_loss, label='Validation loss')
plt.title("Loss")
plt.legend()
plt.grid()

plt.show()

# %%
# Demonstration using AUC and ROC Plot

import sklearn.metrics as metrics
from sklearn.metrics import roc_auc_score

def plot_auc_roc(model,valid_loader, version='title', threshold=0.5):
    y_pred = []
    y_true = []
    model.eval()
    with torch.no_grad():
        for inputs, labels in valid_loader :

            batch_size = inputs.size(0)

            h_val = model.init_hidden(batch_size)

            # h_val = tuple([each.data for each in h_val]) # Correct for SimpleRNN
            h_val = h_val.detach() # Correct for SimpleRNN and GRU

            inputs, labels = inputs.to(device), labels.to(device)

            output, h_val = model(inputs, h_val)

            output = (output > threshold).int()
            y_pred.extend(output.tolist())
            y_true.extend(labels.tolist())

    print('AUC ROC :')
    fpr, tpr, threshold = metrics.roc_curve(y_true, y_pred)
    roc_auc = metrics.auc(fpr, tpr)

    print(roc_auc)
    print('----------------------------------------------------------')

    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
plot_auc_roc(model, valid_loader)
# Out:
# AUC ROC :
# 0.8413870346758668
# ----------------------------------------------------------

# %% [markdown]
# **Task 5: Test the Model by grabing random reviews from**

# %%
def predict_text(text):
        word_seq = np.array([vocab[clean_string(word)] for word in text.split()
                         if clean_string(word) in vocab.keys()])
        word_seq = np.expand_dims(word_seq, axis=0)
        pad =  torch.from_numpy(padding (word_seq, 500))
        inputs = pad.to(device)
        batch_size = 1
        h = model.init_hidden(batch_size)
        # h = tuple([each.data for each in h]) # Correct for LSTM
        h = h.detach() # Correct for SimpleRNN and GRU
        output, h = model(inputs, h)
        return output.item()

index = 30
print(df['review'][index])
print('='*70)
print(f'Actual sentiment is  : {df["sentiment"][index]}')
print('='*70)
score = predict_text(df['review'][index])
status = "positive" if score > 0.5 else "negative"
score = (1 - score) if status == "negative" else score
print(f'Predicted sentiment is {status} with a probability of {score}\n')

index = 32
print(df['review'][index])
print('='*70)
print(f'Actual sentiment is  : {df["sentiment"][index]}')
print('='*70)
prob = predict_text(df['review'][index])
status = "positive" if prob > 0.5 else "negative"
prob = (1 - prob) if status == "negative" else prob
print(f'predicted sentiment is {status} with a probability of {prob}\n')
# Out:
# Taut and organically gripping, Edward Dmytryk's Crossfire is a distinctive suspense thriller, an unlikely "message" movie using the look and devices of the noir cycle.<br /><br />Bivouacked in Washington, DC, a company of soldiers cope with their restlessness by hanging out in bars. Three of them end up at a stranger's apartment where Robert Ryan, drunk and belligerent, beats their host (Sam Levene) to death because he happens to be Jewish. Police detective Robert Young investigates with the help of Robert Mitchum, who's assigned to Ryan's outfit. Suspicion falls on the second of the three (George Cooper), who has vanished. Ryan slays the third buddy (Steve Brodie) to insure his silence before Young closes in.<br /><br />Abetted by a superior script by John Paxton, Dmytryk draws precise performances from his three starring Bobs. Ryan, naturally, does his prototypical Angry White Male (and to the hilt), while Mitchum underplays with his characteristic alert nonchalance (his role, however, is not central); Young may never have been better. Gloria Grahame gives her first fully-fledged rendition of the smart-mouthed, vulnerable tramp, and, as a sad sack who's leeched into her life, Paul Kelly haunts us in a small, peripheral role that he makes memorable.<br /><br />The politically engaged Dmytryk perhaps inevitably succumbs to sermonizing, but it's pretty much confined to Young's reminiscence of how his Irish grandfather died at the hands of bigots a century earlier (thus, incidentally, stretching chronology to the limit). At least there's no attempt to render an explanation, however glib, of why Ryan hates Jews (and hillbillies and...).<br /><br />Curiously, Crossfire survives even the major change wrought upon it -- the novel it's based on (Richard Brooks' The Brick Foxhole) dealt with a gay-bashing murder. But homosexuality in 1947 was still Beyond The Pale. News of the Holocaust had, however, begun to emerge from the ashes of Europe, so Hollywood felt emboldened to register its protest against anti-Semitism (the studios always quaked at the prospect of offending any potential ticket buyer).<br /><br />But while the change from homophobia to anti-Semitism works in general, the specifics don't fit so smoothly. The victim's chatting up a lonesome, drunk young soldier then inviting him back home looks odd, even though (or especially since) there's a girlfriend in tow. It raises the question whether this scenario was retained inadvertently or left in as a discreet tip-off to the original engine generating Ryan's murderous rage.
# ======================================================================
# Actual sentiment is  : positive
# ======================================================================
# Predicted sentiment is positive with a probability of 0.9999936819076538
#
# My first exposure to the Templarios & not a good one. I was excited to find this title among the offerings from Anchor Bay Video, which has brought us other cult classics such as "Spider Baby". The print quality is excellent, but this alone can't hide the fact that the film is deadly dull. There's a thrilling opening sequence in which the villagers exact a terrible revenge on the Templars (& set the whole thing in motion), but everything else in the movie is slow, ponderous &, ultimately, unfulfilling. Adding insult to injury: the movie was dubbed, not subtitled, as promised on the video jacket.
# ======================================================================
# Actual sentiment is  : negative
# ======================================================================
# predicted sentiment is negative with a probability of 0.9989340826869011
